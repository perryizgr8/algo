# %% [markdown]
# # Sources
#
# Upstox - https://upstox.com/developer/api-documentation/instruments/
#
# NSE200 - https://www.nseindia.com/products-services/indices-nifty200-index
#
# Vlookup - "C:\Users\perry\OneDrive\nifty200\ind_nifty200list.xlsx"

# %%
# open xlsx with nifty200 symbols and upstox instrument key
import pandas as pd

# Specify the file path
file_path = 'ind_nifty200list.xlsx'

# Read the Excel file
df = pd.read_excel(file_path)

# Print the DataFrame
# print(df)

# %%
from datetime import date, timedelta, datetime
import requests

def datesort(crow):
    dt = crow[0]
    return int(datetime.fromisoformat(dt).timestamp())

def get_6m_returns(instkey):
    ed = str(date.today())
    sd = str(date.today() - timedelta(weeks=26))
    url = f"https://api-v2.upstox.com/historical-candle/{instkey}/month/{ed}/{sd}"
    h = {
        "Api-Version": "2.0",
        "Accept": "application/json",
        "Authorization": "***REMOVED***",
    }

    # https://upstox.com/developer/api-documentation/get-historical-candle-data/
    resp = requests.get(url, headers=h)
    if resp.status_code != 200:
        print(f"inst: {instkey} err: {resp}")
        return None
    rjson = resp.json()
    
    if rjson["status"] != "success":
        raise Exception(rjson["status"])
    
    # print(f"{rjson}")
    candles = rjson["data"]["candles"]
    candles.sort(key=datesort, reverse=True)
    # for c in candles:
    #     print(f"date: {c[0]} close: {c[4]}")

    if candles:
        start_price = candles[-1][4]
        end_price = candles[0][4]
        return (end_price - start_price)/start_price
    return 0

# print(get_12m_returns("NSE_EQ|INE084A01016"))
# print(get_12m_returns("NSE_EQ|INE498L01015"))

# %%
print(get_6m_returns("NSE_EQ|INE121A08PJ0"))
# Out:
# 0

# %%
# Sort C200 by previous 6 months returns decreasing

import pandas as pd

sym_returns = dict()

def apply_12m_returns(row):
    # print(row)
    sym_returns[row['Symbol']] = get_6m_returns(row['instrument_key'])

df = pd.read_excel('ind_nifty200list.xlsx')
_ = df.apply(apply_12m_returns, axis='columns')

t200 = []
for k,v in sorted(sym_returns.items(), key=lambda x: x[1], reverse=True):
    t200.append({"symbol": k, "gain": v})

print(t200)
# Out:
# [{'symbol': 'PAYTM', 'gain': 1.1121344119477286}, {'symbol': 'BSE', 'gain': 0.8175446748368858}, {'symbol': 'COFORGE', 'gain': 0.4570601597420678}, {'symbol': 'KALYANKJIL', 'gain': 0.3850144667265291}, {'symbol': 'PERSISTENT', 'gain': 0.3365004892194886}, {'symbol': 'DIXON', 'gain': 0.30487916934668763}, {'symbol': 'LUPIN', 'gain': 0.29805409072686345}, {'symbol': 'DIVISLAB', 'gain': 0.29444462574378066}, {'symbol': 'HCLTECH', 'gain': 0.25890654973965477}, {'symbol': 'MFSL', 'gain': 0.2545538746526705}, {'symbol': 'MANKIND', 'gain': 0.24906068006763113}, {'symbol': 'ZOMATO', 'gain': 0.24017750299162338}, {'symbol': 'BHARTIHEXA', 'gain': 0.23503603885929178}, {'symbol': 'BAJAJHLDNG', 'gain': 0.2286776980524234}, {'symbol': 'PAGEIND', 'gain': 0.2277160617759631}, {'symbol': 'POLICYBZR', 'gain': 0.2014313830738952}, {'symbol': 'PIIND', 'gain': 0.20103981572885812}, {'symbol': 'APOLLOHOSP', 'gain': 0.19976720500509237}, {'symbol': 'VOLTAS', 'gain': 0.1995652764570031}, {'symbol': 'HDFCLIFE', 'gain': 0.19065624737417033}, {'symbol': 'SUNPHARMA', 'gain': 0.1898609330308709}, {'symbol': 'SUZLON', 'gain': 0.182368520620507}, {'symbol': 'TECHM', 'gain': 0.17548152550075158}, {'symbol': 'ICICIPRULI', 'gain': 0.17277530130427599}, {'symbol': 'INDHOTEL', 'gain': 0.1725461963042957}, {'symbol': 'PATANJALI', 'gain': 0.1714213899710946}, {'symbol': 'INFY', 'gain': 0.16799106430509017}, {'symbol': 'FEDERALBNK', 'gain': 0.16654442877291967}, {'symbol': 'OFSS', 'gain': 0.16553922436692045}, {'symbol': 'MPHASIS', 'gain': 0.16356272007490166}, {'symbol': 'HINDPETRO', 'gain': 0.15341764528756394}, {'symbol': 'TRENT', 'gain': 0.14947489438579512}, {'symbol': 'MAXHEALTH', 'gain': 0.14734492106522087}, {'symbol': 'TORNTPHARM', 'gain': 0.1463654927811413}, {'symbol': 'ALKEM', 'gain': 0.14327787071633918}, {'symbol': 'OBEROIRLTY', 'gain': 0.1421775449525697}, {'symbol': 'UNITDSPR', 'gain': 0.13486094790442624}, {'symbol': 'TORNTPOWER', 'gain': 0.13060597971169235}, {'symbol': 'NAUKRI', 'gain': 0.12802375531436738}, {'symbol': 'ITC', 'gain': 0.12508825606024956}, {'symbol': 'HDFCAMC', 'gain': 0.1230185560814364}, {'symbol': 'WIPRO', 'gain': 0.10517626493153341}, {'symbol': 'LTIM', 'gain': 0.10063044911375003}, {'symbol': 'AUROPHARMA', 'gain': 0.09932924809539587}, {'symbol': 'SONACOMS', 'gain': 0.09828393135725429}, {'symbol': 'BAJAJFINSV', 'gain': 0.09545697824512792}, {'symbol': 'BHARTIARTL', 'gain': 0.08715072192791118}, {'symbol': 'JUBLFOOD', 'gain': 0.07811806480248558}, {'symbol': 'CIPLA', 'gain': 0.07549972987574281}, {'symbol': 'RVNL', 'gain': 0.07525204032645215}, {'symbol': 'JSWSTEEL', 'gain': 0.06967257112184647}, {'symbol': 'ICICIGI', 'gain': 0.06739124360872853}, {'symbol': 'TCS', 'gain': 0.06220304035449455}, {'symbol': 'NLCINDIA', 'gain': 0.05600666250260249}, {'symbol': 'OIL', 'gain': 0.054973550461570375}, {'symbol': 'IREDA', 'gain': 0.05324511657214879}, {'symbol': 'SBILIFE', 'gain': 0.05228057240524146}, {'symbol': 'NTPC', 'gain': 0.05101096867979372}, {'symbol': 'BRITANNIA', 'gain': 0.049602323054304946}, {'symbol': 'ICICIBANK', 'gain': 0.04939146382127376}, {'symbol': 'NYKAA', 'gain': 0.047041487191113195}, {'symbol': 'TVSMOTOR', 'gain': 0.04357570247584421}, {'symbol': 'BAJAJ-AUTO', 'gain': 0.043018844095499206}, {'symbol': 'HDFCBANK', 'gain': 0.04195866492457542}, {'symbol': 'M&M', 'gain': 0.037761847452601464}, {'symbol': 'SHRIRAMFIN', 'gain': 0.03312725399278716}, {'symbol': 'LT', 'gain': 0.03152080485845943}, {'symbol': 'BOSCHLTD', 'gain': 0.030365797843001488}, {'symbol': 'INDIANB', 'gain': 0.02841429880843263}, {'symbol': 'MARICO', 'gain': 0.027487765089722713}, {'symbol': 'EICHERMOT', 'gain': 0.024031928439208677}, {'symbol': 'BPCL', 'gain': 0.02138509623293305}, {'symbol': 'CGPOWER', 'gain': 0.0163899531715623}, {'symbol': 'HINDUNILVR', 'gain': 0.014011039000424429}, {'symbol': 'SOLARINDS', 'gain': 0.012853265208366707}, {'symbol': 'COLPAL', 'gain': 0.009760301074512425}, {'symbol': 'VEDL', 'gain': 0.008590308370044002}, {' ...

# %%
for s in t200:
    print(f"{s}")
# Out:
# {'symbol': 'PAYTM', 'gain': 1.1121344119477286}
# {'symbol': 'BSE', 'gain': 0.8175446748368858}
# {'symbol': 'COFORGE', 'gain': 0.4570601597420678}
# {'symbol': 'KALYANKJIL', 'gain': 0.3850144667265291}
# {'symbol': 'PERSISTENT', 'gain': 0.3365004892194886}
# {'symbol': 'DIXON', 'gain': 0.30487916934668763}
# {'symbol': 'LUPIN', 'gain': 0.29805409072686345}
# {'symbol': 'DIVISLAB', 'gain': 0.29444462574378066}
# {'symbol': 'HCLTECH', 'gain': 0.25890654973965477}
# {'symbol': 'MFSL', 'gain': 0.2545538746526705}
# {'symbol': 'MANKIND', 'gain': 0.24906068006763113}
# {'symbol': 'ZOMATO', 'gain': 0.24017750299162338}
# {'symbol': 'BHARTIHEXA', 'gain': 0.23503603885929178}
# {'symbol': 'BAJAJHLDNG', 'gain': 0.2286776980524234}
# {'symbol': 'PAGEIND', 'gain': 0.2277160617759631}
# {'symbol': 'POLICYBZR', 'gain': 0.2014313830738952}
# {'symbol': 'PIIND', 'gain': 0.20103981572885812}
# {'symbol': 'APOLLOHOSP', 'gain': 0.19976720500509237}
# {'symbol': 'VOLTAS', 'gain': 0.1995652764570031}
# {'symbol': 'HDFCLIFE', 'gain': 0.19065624737417033}
# {'symbol': 'SUNPHARMA', 'gain': 0.1898609330308709}
# {'symbol': 'SUZLON', 'gain': 0.182368520620507}
# {'symbol': 'TECHM', 'gain': 0.17548152550075158}
# {'symbol': 'ICICIPRULI', 'gain': 0.17277530130427599}
# {'symbol': 'INDHOTEL', 'gain': 0.1725461963042957}
# {'symbol': 'PATANJALI', 'gain': 0.1714213899710946}
# {'symbol': 'INFY', 'gain': 0.16799106430509017}
# {'symbol': 'FEDERALBNK', 'gain': 0.16654442877291967}
# {'symbol': 'OFSS', 'gain': 0.16553922436692045}
# {'symbol': 'MPHASIS', 'gain': 0.16356272007490166}
# {'symbol': 'HINDPETRO', 'gain': 0.15341764528756394}
# {'symbol': 'TRENT', 'gain': 0.14947489438579512}
# {'symbol': 'MAXHEALTH', 'gain': 0.14734492106522087}
# {'symbol': 'TORNTPHARM', 'gain': 0.1463654927811413}
# {'symbol': 'ALKEM', 'gain': 0.14327787071633918}
# {'symbol': 'OBEROIRLTY', 'gain': 0.1421775449525697}
# {'symbol': 'UNITDSPR', 'gain': 0.13486094790442624}
# {'symbol': 'TORNTPOWER', 'gain': 0.13060597971169235}
# {'symbol': 'NAUKRI', 'gain': 0.12802375531436738}
# {'symbol': 'ITC', 'gain': 0.12508825606024956}
# {'symbol': 'HDFCAMC', 'gain': 0.1230185560814364}
# {'symbol': 'WIPRO', 'gain': 0.10517626493153341}
# {'symbol': 'LTIM', 'gain': 0.10063044911375003}
# {'symbol': 'AUROPHARMA', 'gain': 0.09932924809539587}
# {'symbol': 'SONACOMS', 'gain': 0.09828393135725429}
# {'symbol': 'BAJAJFINSV', 'gain': 0.09545697824512792}
# {'symbol': 'BHARTIARTL', 'gain': 0.08715072192791118}
# {'symbol': 'JUBLFOOD', 'gain': 0.07811806480248558}
# {'symbol': 'CIPLA', 'gain': 0.07549972987574281}
# {'symbol': 'RVNL', 'gain': 0.07525204032645215}
# {'symbol': 'JSWSTEEL', 'gain': 0.06967257112184647}
# {'symbol': 'ICICIGI', 'gain': 0.06739124360872853}
# {'symbol': 'TCS', 'gain': 0.06220304035449455}
# {'symbol': 'NLCINDIA', 'gain': 0.05600666250260249}
# {'symbol': 'OIL', 'gain': 0.054973550461570375}
# {'symbol': 'IREDA', 'gain': 0.05324511657214879}
# {'symbol': 'SBILIFE', 'gain': 0.05228057240524146}
# {'symbol': 'NTPC', 'gain': 0.05101096867979372}
# {'symbol': 'BRITANNIA', 'gain': 0.049602323054304946}
# {'symbol': 'ICICIBANK', 'gain': 0.04939146382127376}
# {'symbol': 'NYKAA', 'gain': 0.047041487191113195}
# {'symbol': 'TVSMOTOR', 'gain': 0.04357570247584421}
# {'symbol': 'BAJAJ-AUTO', 'gain': 0.043018844095499206}
# {'symbol': 'HDFCBANK', 'gain': 0.04195866492457542}
# {'symbol': 'M&M', 'gain': 0.037761847452601464}
# {'symbol': 'SHRIRAMFIN', 'gain': 0.03312725399278716}
# {'symbol': 'LT', 'gain': 0.03152080485845943}
# {'symbol': 'BOSCHLTD', 'gain': 0.030365797843001488}
# {'symbol': 'INDIANB', 'gain': 0.02841429880843263}
# {'symbol': 'MARICO', 'gain': 0.027487765089722713}
# {'symbol': 'EICHERMOT', 'gain': 0.024031928439208677}
# {'symbol': 'BPCL', 'gain': 0.02138509623293305}
# {'symbol': 'CGPOWER', 'gain': 0.0163899531715623}
# {'symbol': 'HINDUNILVR', 'gain': 0.014011039000424429}
# {'symbol': 'SOLARINDS', 'gain': 0.012853265208366707}
# {'symbol': 'COLPAL', 'gain': 0.009760301074512425}
# {'symbol': 'VEDL', 'gain': 0.008590308370044002}
# {'symbol': 'DRREDDY', 'gain': 0.0074164181447182904}
# {'symbol': 'MUTHOOTFIN', 'gain': 0.004844502603224126}
# {'symbol': 'CHOLAFIN', 'gain': 0}
# {'symbol': 'MOTHERSON', 'gain': 0}
# {'symbol': 'TATACHEM', 'gain': -0.0014504578007432773}
# {'symbol': 'POLYCAB', 'gain': -0.0020327917501298046}
# {'symbol': 'PETRONET', 'gain': -0.004087812263436859}
# {'symbol': 'SBIN', 'gain': -0.006831968902762315}
# {'symbol': 'TATAELXSI', 'gain': -0.008655411774787822}
# {'symbol': 'PIDILITIND', 'gain': -0.010525649345510375}
# {'symbol': 'TATATECH', 'gain': -0.016634864719408973}
# {'symbol': 'TATAPOWER', 'gain': -0.01781661370857926}
# {'symbol': 'IDBI', 'gain': -0.019411694652852154}
# {'symbol': 'RECLTD', 'gain': -0.020650932622763653}
# {'symbol': 'APLAPOLLO', 'gain': -0.02224651192695937}
# {'symbol': 'UPL', 'gain': -0.023211001138652886}
# {'symbol': 'BEL', 'gain': -0.026642693690748537}
# {'symbol': 'MAZDOCK', 'gain': -0.027408938560534273}
# {'symbol': 'SUNDARMFIN', 'gain': -0.02960421151345929}
# {'symbol': 'JSWENERGY', 'gain': -0.030565010211027973}
# {'symbol': 'BAJFINANCE', 'gain': -0.030861985370069827}
# {'symbol': 'KOTAKBANK', 'gain': -0.031456310679611674}
# {'symbol': 'SBICARD', 'gain': -0.034777808446039254}
# {'symbol': 'NMDC', 'gain': -0.04096728307254628}
# {'symbol': 'ONGC', 'gain': -0.04248723559445652}
# {'symbol': 'TATACOMM', 'gain': -0.043031626627841116}
# {'symbol': 'POWERGRID', 'gain': -0.04441758573802686}
# {'symbol': 'DLF', 'gain': -0.04698393452561382}
# {'symbol': 'GRASIM', 'gain': -0.04703327154599409}
# {'symbol': 'ABFRL', 'gain': -0.04805382027871216}
# {'symbol': 'ASIANPAINT', 'gain': -0.0505990641230011}
# {'symbol': 'INDIGO', 'gain': -0.05328445574410221}
# {'symbol': 'SRF', 'gain': -0.053406128774040086}
# {'symbol': 'ULTRACEMCO', 'gain': -0.053527198553295734}
# {'symbol': 'MARUTI', 'gain': -0.060732849420592774}
# {'symbol': 'ADANIENSOL', 'gain': -0.06126234521481929}
# {'symbol': 'HINDALCO', 'gain': -0.062144041525484695}
# {'symbol': 'TITAN', 'gain': -0.06402385288760937}
# {'symbol': 'BANKBARODA', 'gain': -0.06826434277414653}
# {'symbol': 'SIEMENS', 'gain': -0.06881043545979618}
# {'symbol': 'GAIL', 'gain': -0.07005237986791174}
# {'symbol': 'JSWINFRA', 'gain': -0.07277710109622405}
# {'symbol': 'PFC', 'gain': -0.07359307359307368}
# {'symbol': 'BANKINDIA', 'gain': -0.07360385030287947}
# {'symbol': 'LICI', 'gain': -0.0749431099873578}
# {'symbol': 'MRF', 'gain': -0.07805435150779216}
# {'symbol': 'ADANIENT', 'gain': -0.07807311584281516}
# {'symbol': 'ADANIPORTS', 'gain': -0.07847912861105474}
# {'symbol': 'CUMMINSIND', 'gain': -0.07852578242182084}
# {'symbol': 'M&MFIN', 'gain': -0.08133732534930155}
# {'symbol': 'AXISBANK', 'gain': -0.08243430152143842}
# {'symbol': 'ASHOKLEY', 'gain': -0.08268221092232007}
# {'symbol': 'BIOCON', 'gain': -0.08487610367416693}
# {'symbol': 'TIINDIA', 'gain': -0.08656453600986085}
# {'symbol': 'HAVELLS', 'gain': -0.08875658472344161}
# {'symbol': 'GODREJCP', 'gain': -0.09070756259766687}
# {'symbol': 'VBL', 'gain': -0.09243633016262658}
# {'symbol': 'APOLLOTYRE', 'gain': -0.09383650119948324}
# {'symbol': 'TATACONSUM', 'gain': -0.09522073898583079}
# {'symbol': 'ZYDUSLIFE', 'gain': -0.09646631593649613}
# {'symbol': 'NESTLEIND', 'gain': -0.10032723923735622}
# {'symbol': 'FACT', 'gain': -0.10230554851786171}
# {'symbol': 'COALINDIA', 'gain': -0.10377258797421529}
# {'symbol': 'POONAWALLA', 'gain': -0.10559765338548043}
# {'symbol': 'ADANIGREEN', 'gain': -0.10635621645796065}
# {'symbol': 'JINDALSTEL', 'gain': -0.11140367675220235}
# {'symbol': 'DABUR', 'gain': -0.11519893457632768}
# {'symbol': 'JIOFIN', 'gain': -0.11754851319279623}
# {'symbol': 'SHREECEM', 'gain': -0.11974711521901377}
# {'symbol': 'IGL', 'gain': -0.1217986896962477}
# {'symbol': 'ESCORTS', 'gain': -0.12323646448812252}
# {'symbol': 'BALKRISIND', 'gain': -0.12386187674202534}
# {'symbol': 'ACC', 'gain': -0.1251026135430786}
# {'symbol': 'BANDHANBNK', 'gain': -0.1280793012071842}
# {'symbol': 'KPITTECH', 'gain': -0.1299281235662946}
# {'symbol': 'INDUSTOWER', 'gain': -0.1308286703970158}
# {'symbol': 'CANBK', 'gain': -0.13208336820959238}
# {'symbol': 'DELHIVERY', 'gain': -0.13320004998125692}
# {'symbol': 'AUBANK', 'gain': -0.13600178558142992}
# {'symbol': 'UNIONBANK', 'gain': -0.14024434852586146}
# {'symbol': 'HEROMOTOCO', 'gain': -0.1452971539178437}
# {'symbol': 'IRFC', 'gain': -0.1453886427708418}
# {'symbol': 'YESBANK', 'gain': -0.14900802026171384}
# {'symbol': 'PNB', 'gain': -0.14984585429174102}
# {'symbol': 'BHARATFORG', 'gain': -0.1498488340766905}
# {'symbol': 'TATASTEEL', 'gain': -0.15194529050054595}
# {'symbol': 'IOC', 'gain': -0.15268973012135478}
# {'symbol': 'SJVN', 'gain': -0.15323254577224038}
# {'symbol': 'AMBUJACEM', 'gain': -0.15718015665796348}
# {'symbol': 'ABCAPITAL', 'gain': -0.15751330065770178}
# {'symbol': 'IRCTC', 'gain': -0.15845337376800606}
# {'symbol': 'GODREJPROP', 'gain': -0.16294148820100385}
# {'symbol': 'HAL', 'gain': -0.16405945766253496}
# {'symbol': 'PRESTIGE', 'gain': -0.16524886399661842}
# {'symbol': 'MAHABANK', 'gain': -0.16633235611788305}
# {'symbol': 'GMRINFRA', 'gain': -0.16858237547892707}
# {'symbol': 'ABB', 'gain': -0.17023519297129866}
# {'symbol': 'IOB', 'gain': -0.17377100186683264}
# {'symbol': 'PHOENIXLTD', 'gain': -0.1768246802106847}
# {'symbol': 'DMART', 'gain': -0.17856574972173636}
# {'symbol': 'RELIANCE', 'gain': -0.17992206464801333}
# {'symbol': 'ADANIPOWER', 'gain': -0.18035068188143616}
# {'symbol': 'NHPC', 'gain': -0.18222442899702093}
# {'symbol': 'TATAMOTORS', 'gain': -0.1862086385450871}
# {'symbol': 'IDFCFIRSTB', 'gain': -0.20119279454722494}
# {'symbol': 'LICHSGFIN', 'gain': -0.20306224899598388}
# {'symbol': 'ATGL', 'gain': -0.20468749999999997}
# {'symbol': 'SAIL', 'gain': -0.20477632021527084}
# {'symbol': 'BHEL', 'gain': -0.205451221538973}
# {'symbol': 'CONCOR', 'gain': -0.20625479662317736}
# {'symbol': 'IRB', 'gain': -0.2070294435023895}
# {'symbol': 'LODHA', 'gain': -0.22164211366432776}
# {'symbol': 'HUDCO', 'gain': -0.22290184921763861}
# {'symbol': 'EXIDEIND', 'gain': -0.2257750221434898}
# {'symbol': 'LTF', 'gain': -0.22663796434288225}
# {'symbol': 'SUPREMEIND', 'gain': -0.22801759599724633}
# {'symbol': 'HINDZINC', 'gain': -0.24400806391398489}
# {'symbol': 'ASTRAL', 'gain': -0.2486559139784947}
# {'symbol': 'MRPL', 'gain': -0.24975505062287126}
# {'symbol': 'INDUSINDBK', 'gain': -0.2804370092181632}
# {'symbol': 'BDL', 'gain': -0.34216459977452085}
# {'symbol': 'COCHINSHIP', 'gain': -0.34634223416021487}
# {'symbol': 'IDEA', 'gain': -0.5595304639463388}

# %%
# select top 40 (T40) and top 20 (T20) from it.

t40 = t200[:40]
t20 = t200[:20]

# %%
# Open portfolio.csv, which contains all symbols held currently, call it HXX

import pandas as pd

df = pd.read_csv("portfolio6.csv")

sell = []
buy = []
hold = []

for i, r in df.iterrows():
    if not any(t['symbol'] == r['Symbol'] for t in t40):
        sell.append(r['Symbol'])
    elif any(t['symbol'] == r['Symbol'] for t in t20):
        buy.append(r['Symbol'])
    else:
        hold.append(r['Symbol'])

for t in t20:
    if t['symbol'] not in buy:
        buy.append(t['symbol'])

print(f"buy: {buy}")
print(f"sell: {sell}")
print(f"hold: {hold}")
# Out:
# buy: ['PAYTM', 'BSE', 'COFORGE', 'KALYANKJIL', 'PERSISTENT', 'DIXON', 'LUPIN', 'DIVISLAB', 'HCLTECH', 'MFSL', 'MANKIND', 'ZOMATO', 'BHARTIHEXA', 'BAJAJHLDNG', 'PAGEIND', 'POLICYBZR', 'PIIND', 'APOLLOHOSP', 'VOLTAS', 'HDFCLIFE']
# sell: []
# hold: []

# %%
# Update portfolio.csv

import pandas as pd

df = pd.read_csv("portfolio6.csv")

for s in sell:
    df = df[df['Symbol'] != s]

for b in buy:
    if b not in df['Symbol'].values:
        r = pd.DataFrame({'Symbol': [b], 'Units': [0]})
        df = pd.concat([df, r], ignore_index=True)

# Save the updated portfolio once at the end
df.to_csv('portfolio6.csv', index=False)
print(f"Portfolio updated with {len(buy)} buys and {len(sell)} sells")
